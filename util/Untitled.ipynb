# %%
import pandas as pd

# %%
df = pd.read_csv('NFLSalaryCap.data')

# %%
df[(df.Team == 'seattle-seahawks') & (df.Year == 2017)]
# Out:
#        Unnamed: 0  Year              Team  index  \
# 20809       20809  2017  seattle-seahawks      0
# 20810       20810  2017  seattle-seahawks      1
# 20811       20811  2017  seattle-seahawks      2
# 20812       20812  2017  seattle-seahawks      3
# 20813       20813  2017  seattle-seahawks      4
# 20814       20814  2017  seattle-seahawks      5
# 20815       20815  2017  seattle-seahawks      6
# 20816       20816  2017  seattle-seahawks      7
# 20817       20817  2017  seattle-seahawks      8
# 20818       20818  2017  seattle-seahawks      9
# 20819       20819  2017  seattle-seahawks     10
# 20820       20820  2017  seattle-seahawks     11
# 20821       20821  2017  seattle-seahawks     12
# 20822       20822  2017  seattle-seahawks     13
# 20823       20823  2017  seattle-seahawks     14
# 20824       20824  2017  seattle-seahawks     15
# 20825       20825  2017  seattle-seahawks     16
# 20826       20826  2017  seattle-seahawks     17
# ...

# %%
foo.head()
# Out:
#        Unnamed: 0  Year              Team  index  \
# 20137       20137  2011  seattle-seahawks      0
# 20138       20138  2011  seattle-seahawks      1
# 20139       20139  2011  seattle-seahawks      2
# 20140       20140  2011  seattle-seahawks      3
# 20141       20141  2011  seattle-seahawks      4
#
#                                   Player Position Base_Salary Signing_Bonus  \
# 20137            Okung\r\nRussell Okung        LT  $1,400,000      $280,000
# 20138         Gallery\r\nRobert Gallery         T  $4,000,000      $333,333
# 20139          Mebane\r\nBrandon Mebane        DT  $4,000,000      $200,000
# 20140             Thomas\r\nEarl Thomas        FS    $625,000      $100,000
# 20141  Whitehurst\r\nCharlie Whitehurst        QB  $4,000,000             -
#
#       Roster_Bonus Option_Bonus Workout_Bonus Restruct_Bonus        Misc  \
# 20137            -   $2,000,000      $200,000              -  $5,000,000
# ...
